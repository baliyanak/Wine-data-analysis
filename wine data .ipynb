# %%
import pandas as pd

import seaborn as sb
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import accuracy_score

# %%
df=pd.read_csv('wine data.csv')

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
#statistical info
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996750
# 75%       0.090000            21.000000             62.000000     0.997835
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1599.000000  1599.000000  1599.000000  1599.000000
# mean      3.311113     0.658149    10.422983     5.636023
# std       0.154386     0.169507     1.065668     0.807569
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.210000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %%
#data type
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
df.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# fixed acidity               0.114777   0.093705            -0.153794
# volatile acidity            0.001918   0.061298            -0.010504
# citric acid                 0.143577   0.203823            -0.060978
# residual sugar              1.000000   0.055610             0.187049
# chlorides                   0.055610   1.000000             0.005562
# free sulfur dioxide         0.187049   0.005562             1.000000
# total sulfur dioxide        0.203028   0.047400             0.667666
# density                     0.355283   0.200632            -0.021946
# pH                         -0.085652  -0.265026             0.070377
# sulphates                   0.005527   0.371260             0.051658
# alcohol                     0.042075  -0.221141            -0.069408
# quality                     0.013732  -0.128907            -0.050656
#
#                       total sulfur dioxide   density        pH  sulphates  \
# fixed acidity                    -0.113181  0.668047 -0.682978   0.183006
# volatile acidity                  0.076470  0.022026  0.234937  -0.260987
# citric acid                       0.035533  0.364947 -0.541904   0.312770
# residual sugar                    0.203028  0.355283 -0.085652   0.005527
# chlorides                         0.047400  0.200632 -0.265026   0.371260
# free sulfur dioxide               0.667666 -0.021946  0.070377   0.051658
# total sulfur dioxide              1.000000  0.071269 -0.066495   0.042947
# density                           0.071269  1.000000 -0.341699   0.148506
# pH                               -0.066495 -0.341699  1.000000  -0.196648
# sulphates                         0.042947  0.148506 -0.196648   1.000000
# alcohol                          -0.205654 -0.496180  0.205633   0.093595
# quality                          -0.185100 -0.174919 -0.057731   0.251397
#
#                        alcohol   quality
# fixed acidity        -0.061668  0.124052
# volatile acidity     -0.202288 -0.390558
# citric acid           0.109903  0.226373
# residual sugar        0.042075  0.013732
# chlorides            -0.221141 -0.128907
# free sulfur dioxide  -0.069408 -0.050656
# total sulfur dioxide -0.205654 -0.185100
# density              -0.496180 -0.174919
# pH                    0.205633 -0.057731
# sulphates             0.093595  0.251397
# alcohol               1.000000  0.476166
# quality               0.476166  1.000000

# %%
sb.set_theme(style='whitegrid')
sb.violinplot(x='quality',y='alcohol',data=df,inner='box')
plt.title('alcohol vs quality violin plot')
plt.show()

# %%
sb.set_theme(style='whitegrid')
sb.kdeplot(x='quality',y='total sulfur dioxide',data=df,cmap='mako')
plt.title('quality vs total sulfur dioxide')
plt.show()

# %%
sb.displot(data=df,x='volatile acidity',hue='quality',kind='kde',height=6,multiple="fill", clip=(0, None),palette="ch:rot=-.25,hue=1,light=.75")
plt.title('Conditional kernel density estimate of volatile acidity')
plt.show()

# %%
plt.figure(figsize=(40,20))
sb.boxplot(data=df)
plt.show()

# %%
sb.pairplot(df,hue = 'quality')
plt.title('Pair wise plot')
plt.show()

# %%
features = ['volatile acidity','citric acid','sulphates','alcohol','fixed acidity','chlorides','total sulfur dioxide','density','residual sugar','free sulfur dioxide','pH']
x = df[features]

# %%
x.describe()
# Out:
#        volatile acidity  citric acid    sulphates      alcohol  fixed acidity  \
# count       1599.000000  1599.000000  1599.000000  1599.000000    1599.000000
# mean           0.527821     0.270976     0.658149    10.422983       8.319637
# std            0.179060     0.194801     0.169507     1.065668       1.741096
# min            0.120000     0.000000     0.330000     8.400000       4.600000
# 25%            0.390000     0.090000     0.550000     9.500000       7.100000
# 50%            0.520000     0.260000     0.620000    10.200000       7.900000
# 75%            0.640000     0.420000     0.730000    11.100000       9.200000
# max            1.580000     1.000000     2.000000    14.900000      15.900000
#
#          chlorides  total sulfur dioxide      density  residual sugar  \
# count  1599.000000           1599.000000  1599.000000     1599.000000
# mean      0.087467             46.467792     0.996747        2.538806
# std       0.047065             32.895324     0.001887        1.409928
# min       0.012000              6.000000     0.990070        0.900000
# 25%       0.070000             22.000000     0.995600        1.900000
# 50%       0.079000             38.000000     0.996750        2.200000
# 75%       0.090000             62.000000     0.997835        2.600000
# max       0.611000            289.000000     1.003690       15.500000
#
#        free sulfur dioxide           pH
# count          1599.000000  1599.000000
# mean             15.874922     3.311113
# std              10.460157     0.154386
# min               1.000000     2.740000
# 25%               7.000000     3.210000
# 50%              14.000000     3.310000
# 75%              21.000000     3.400000
# max              72.000000     4.010000

# %%
y = df['quality'].apply(lambda y_data: 1 if y_data>=7 else 0)

# %%
y.value_counts()
# Out:
# 0    1382
# 1     217
# Name: quality, dtype: int64

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,random_state = 3,test_size = 0.25)

# %%
logi = LogisticRegression(max_iter = 1000)
logi.fit(x_train,y_train)
logi_pred = logi.predict(x_test)
print('balanced accuracy score for LOGISTIC REGRESSION : ',balanced_accuracy_score(y_test,logi_pred))
print('accuracy score for LOGISTIC REGRESSION : ',accuracy_score(y_test,logi_pred))
# Out:
# balanced accuracy score for LOGISTIC REGRESSION :  0.615989662340581
# accuracy score for LOGISTIC REGRESSION :  0.885

# %%
sb.distplot(x=logi_pred)
plt.title('logistic predictions')
plt.show()
# Out:
# C:\Users\baliy\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sb.regplot(x=y_test,y=logi_pred)
plt.show()

# %%
ran = RandomForestClassifier()
ran.fit(x_train,y_train)
ran_pred = ran.predict(x_test)
print('balanced accuracy sore for RANDOM FOREST CLASSIFIER : ',balanced_accuracy_score(y_test,ran_pred))
print('accuracy sore for RANDOM FOREST CLASSIFIER : ',accuracy_score(y_test,ran_pred))
# Out:
# balanced accuracy sore for RANDOM FOREST CLASSIFIER :  0.7953255800887691
# accuracy sore for RANDOM FOREST CLASSIFIER :  0.935

# %%
sb.distplot(x=ran_pred)
plt.title('random forest predictions')
plt.show()
# Out:
# C:\Users\baliy\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sb.regplot(x=y_test,y=ran_pred)
plt.show()
